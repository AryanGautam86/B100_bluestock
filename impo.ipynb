# %%
# python -m venv B100 [create env]
# B100\Scripts\activate [activate]
# mkdir etl,notebooks,powerbi,data,data\raw,data\clean

# %%
# $env:Path += ";C:\Program Files\PostgreSQL\17\bin" [curr add dir]
# psql --version
# & "C:\Program Files\PostgreSQL\17\bin\psql.exe" -U postgres [connect postgres] use sql
# \l [see created databases]
# \q [back]

# %%
# tree /F [shows folder structure as a tree]

# %%
# psql -U postgres -d bluestock_dw [open sql]

# %%
# \i 'C:/Users/aryan/B100_bluestock/etl/schema.sql' [execute command]

# %%
# \dt [list all table in current database]
